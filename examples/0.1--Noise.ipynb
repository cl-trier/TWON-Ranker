# %%
import sys

sys.path.append('..')

# %%
import seaborn as sns

from src import modules

# %%
LOW_BOUND: float = .8
HIGH_BOUND: float = 1.4

N: int = 1_000_000

# %%
FUNCTION = modules.Noise(low=LOW_BOUND, high=HIGH_BOUND)

# %%
sns.kdeplot(
    FUNCTION.draw_samples(N),
    fill=True,
    clip=[LOW_BOUND, HIGH_BOUND],
)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.displot(FUNCTION.draw_samples(N))
